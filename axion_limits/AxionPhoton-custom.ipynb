# %% [markdown]
# # Axion-photon coupling limits vs axion mass

# %% [markdown]
# This is adopted from AxionLimits from https://github.com/cajohare/AxionLimits with modifications

# %%
# %matplotlib notebook
#%matplotlib inline
from numpy import *
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from PlotFuncs_mod import FigSetup, AxionPhoton, MySaveFig, BlackHoleSpins

# %%
# %load_ext autoreload
# %autoreload 2

# %%
plt.rcParams['axes.linewidth'] = 2.5
plt.rc('text', usetex=True)
plt.rc('font', family='serif',size=25)
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{mathpazo}']
# Out:
# <ipython-input-3-f006475440a6>:4: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{mathpazo}']

# %%
# def DMbound(ma):
#     """
#     ma: axion mass [eV]
#     return: ga [1/GeV]
#     """
#     benchmark = 238576996171.548  # [1/Gyr] this is (gag, ma) = (1/GeV, eV)
#     Gamma = benchmark/10. * ma**3
#     gag = np.sqrt(1./Gamma)
#     return gag

# (1e-10/(DMbound(1e-5)))**2

# %%
#FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',mathpazo=True)

# %%
# plot it by hand
fig, ax = plt.subplots(figsize=(10,7))
plt.yscale('log')
plt.xscale('log')
plt.ylim(1e-12, 1e-9)
plt.xlim(1e-7, 1e-3)
plt.xlabel(r'$m_a$ [eV]')
plt.ylabel(r'$g_{a\gamma}$ [GeV$^{-1}$]')

fs = 20 # fontsize
text_on = True
projection = False

# AxionPhoton.Haloscopes(ax)
# hand-pick those from Haloscopes 
# the references are here: 
# https://github.com/cajohare/AxionLimits/tree/master/refs
AxionPhoton.ADMX(ax,projection=projection,fs=fs,text_on=text_on, col=[0.8, 0.8, 0.8], text_shift=[1.7, 0.4e2])
AxionPhoton.RBF_UF(ax,fs=fs-2,text_on=text_on, col=[0.8, 0.8, 0.8], text_shift=[1.1, 0.7])
AxionPhoton.HAYSTAC(ax,projection=projection,text_on=text_on, col=[0.8, 0.8, 0.8], fs=13, text_shift=[0.8,7])
AxionPhoton.CAPP(ax,fs=fs-4,text_on=text_on, col=[0.4, 0.4, 0.4], text_shift=[1.1,300])
AxionPhoton.ORGAN(ax,projection=projection,text_on=text_on, col=[0.8, 0.8, 0.8], fs=15, text_shift=[1,0.3])
AxionPhoton.ADMX_SLIC(ax,fs=fs-8,text_on=text_on, col=[0.8, 0.8, 0.8], text_shift=[0.6,0.5])
AxionPhoton.QUAX(ax,text_on=text_on, text_shift=[0.8, 0.3], col=[0.8, 0.8, 0.8])

AxionPhoton.Helioscopes(ax, text_shift=[1.1, 1.1], col=[0.6, 0.6, 0.6])
AxionPhoton.NeutronStars(ax, fs=fs, text_shift=[3,0.5], col=[0.6, 0.6, 0.6])


plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">
